# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabel311/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Isabel311/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Ranking Signal Analysis
#
# I want to study which observable search and content signals are associated with page visibility and performance. I will focus on signals such as search position, impressions, CTR, engagement, and content characteristics to identify useful patterns for prioritizing pages for review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages should a content or SEO reviewer prioritize for further review?
#
# Who acts on it: A content/SEO reviewer.
#
# Cost of a wrong call: Time may be spent improving pages with little opportunity, while pages with useful improvement signals could be missed.

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/Isabel311/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
print("Dataset exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Working directory: /content/flyrank-ml-internship/flyrank-ml-internship
# Dataset exists: True

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Number of pages: {len(df):,}")

print(
    f"Correlation between avg_position and CTR: "
    f"{df['avg_position'].corr(df['ctr']):.3f}"
)

print(f"Median CTR: {df['ctr'].median():.3f}")
# Out:
# Number of pages: 30,000
# Correlation between avg_position and CTR: -0.073
# Median CTR: 0.070

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis will identify observed and directional relationships between available search and content signals and page performance. These results can support decisions about which pages to review first. They cannot prove that one factor causes another, and they cannot be used to claim that we are predicting Google's algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
